# %% [markdown]
# # Lexical Substitution

# %% [markdown]
# In this homework we find suitable substitutions for a target word in a sentence.

# %% [markdown]
# After three steps, we reach a score of 48.32.

# %% [markdown]
# ## 1. Implement Baseline / Retrofitting

# %%
from lexsub import *

# %% [markdown]
#  Frist turn word vectors into a dictionary:

# %%
def load_wvecs(wvec_file):
    wordVectors = {}
    for key, vector in wvec_file:
        wordVectors[key] = np.zeros(len(vector), dtype=float)
        for index, vecVal in enumerate(vector):
            wordVectors[key][index] = float(vecVal)
        ''' normalize weight vector '''
        wordVectors[key] /= math.sqrt((wordVectors[key]**2).sum() + 1e-6)
    return wordVectors

# %% [markdown]
# Take a look at the first 5 lines:

# %% [markdown]
# Download glove.6B.100d.magnitude if you do not have it:

# %% [markdown]
# !wget http://magnitude.plasticity.ai/glove/medium/glove.6B.100d.magnitude

# %%
from pymagnitude import *
wv = Magnitude("../data/glove.6B.100d.magnitude")
for key, vector in wv[:10]:
    print(key, vector[:5])
# Out:
# the [-0.0065612 -0.0420655  0.1250817 -0.0686479  0.0142879]
# , [-0.0193882  0.0199032  0.1077039 -0.0978882  0.1213604]
# . [-0.0622309  0.0383524  0.0848841 -0.1186634 -0.0702856]
# of [-0.0242819 -0.0385573  0.1426693  0.0269912  0.0849883]
# to [-0.0294079  0.0077549  0.0295846 -0.0076247 -0.0139113]
# and [-0.012695   0.0408041  0.004187  -0.0893432  0.0598521]
# in [ 0.0140624 -0.0364279  0.0271868  0.0219427  0.0627435]
# a [-0.043387   0.007049  -0.0032453 -0.0278637  0.1032215]
# " [-0.0462585 -0.0359123  0.0266947 -0.1106516 -0.0430477]
# 's [ 0.0883406 -0.0303955  0.1102929 -0.1025762 -0.0295324]

# %%
word_vector = load_wvecs(pymagnitude.Magnitude("../data/glove.6B.100d.magnitude"))

# %% [markdown]
# For lexicon, we have tried wordnet and ppdb-xl respectively. Ppdb-xl turns out to give a better performance. Then import this lexicon as a dictionary:

# %%
def load_lexicon(lexicon_file):
    lexicon = {}
    for line in open(lexicon_file, 'r'):
        words = line.lower().strip().split()
        lexicon[words[0]] = [word for word in words[1:]]
    return lexicon

# %% [markdown]
# Take a look at the first five lines of the lexicon:

# %% [raw]
# fawn crawl
# reallocations re-allocations reassignments redeployments diversions overrides redistributions
# heavily-fortified strongly-fortified
# 360.00 360
# 1,800 1800 1.8 1.800 1-800

# %% [markdown]
# Then load the file into a dictionary:

# %%
lexicon = load_lexicon("../data/lexicons/ppdb-xl.txt")

# %% [markdown]
# Now we have the word vectors and the lexicon. Our goal is to use these semantic relations in lexicon to augment the word representations in the pre-trained word vectors. We then use the retrofit method introduced in baseline solution. We set the intital iteration to 10, and set initial α=β=1. Below is the implementation of the retrofit function:

# %%
def retrofitting(wordVectors, lexicon, numberOfIteration, alpha=1, beta=1):
    # Q to be equal to Q_hat
    # Initialize Q to be equal to the vectors in q_hat
    q_hat = wordVectors
    q = deepcopy(wordVectors) # copy a mutable new q vector

    # find connected vocab between (wi, wj)
    wvecKey = set(wordVectors.keys())
    lexcionKey = set(lexicon.keys())
    
    # if (wi,wj) are connected by an edge, get word which append in lexicon and word embedding 
    
    exist_word_vector = wvecKey.intersection(lexcionKey)

    # Retrofitting, we want to get new Q which append in lexicon space, therefore, it will not update the

    # So if (wi,wj) are connected by an edge in the ontology then we want qi and qj to be close in vector space.
    # numberOfIteration = 10
    for iteration in range(numberOfIteration):
        # Do Update Q here
        # neighbors q 
        for word in exist_word_vector:
            # The defined neighbours word inside lexicon for this word  
            lexicon_words = set(lexicon[word])
            # Get the neighbours word exists in word vector
            neighbours_words = lexicon_words.intersection(wvecKey)

            num_neighbours_words = len(neighbours_words) 
            if(num_neighbours_words == 0): # No need to update if there is no neighours word found
                continue 

            # alpha = 1
            # beta = 1
            # sum number j of neighbours_words (xi*q_hat) 
            numerator = alpha * q_hat[word]
            # add sum number j of neighbours_words (beta *q) 

            for nei_word in neighbours_words:
                numerator += beta * q[nei_word] 

            denominator = num_neighbours_words * (alpha + beta)

            # update the word vector 
            q[word] = numerator / denominator

    return q # Return matrix of new vector Q here

# %% [markdown]
# Then call the function and save the new word vectors after retrofitting:

# %%
new_retrofitted_magnitude = os.path.join('..', 'data', 'glove.6B.100d.retrofit.magnitude')
new_retrofitted_txt = os.path.join('..' , 'data', 'glove.6B.100d.retrofit.txt')
retrofitted_vector = retrofitting(word_vector, lexicon, 10, 1, 1)
save_word_vecs(retrofitted_vector, new_retrofitted_txt) 
os.system("python3 -m pymagnitude.converter -i " + new_retrofitted_txt + " -o " + new_retrofitted_magnitude)
# Out:
# 0

# %% [markdown]
# Now we run the baseline solution without considering incorporating context words: First introduce the class "LexSub" which contains the function "substitutes" to produce the top ten subsitutes.

# %%
class LexSub:

    def __init__(self, retrofitted_magnitude, wvec_file, retrofitted_vector, topn=10):
        self.retrofitted_magnitude = pymagnitude.Magnitude(retrofitted_magnitude)  # This is the Q_hat vector  100 dimenstional GloVe word vectors
        self.topn = topn 
        self.wvecs = wvec_file
        self.wvecKey = set(self.wvecs.keys())
        self.retrofitted_vector = retrofitted_vector

    def substitutes(self, index, sentence, use_context_word=False):
        "Return ten guesses that are appropriate lexical substitutions for the word at sentence[index]."
        # return the 10 guess word after created the retrofitted word vectors
        substitutes = list(map(lambda k: k[0], self.retrofitted_magnitude.most_similar(sentence[index], topn=15)))
        # Incorporating Context Words
        if use_context_word:
            substitutes = incorporating_context_words(self.retrofitted_vector, self.wvecKey, sentence, index, substitutes, self.topn)
        return substitutes

# %%
lexsub = LexSub(new_retrofitted_magnitude, word_vector, retrofitted_vector, 10)
    
num_lines = sum(1 for line in open('../data/input/dev.txt','r'))
with open("../data/input/dev.txt") as f:
    for line in tqdm.tqdm(f, total=num_lines):
        fields = line.strip().split('\t')
        print(" ".join(lexsub.substitutes(int(fields[0].strip()), fields[1].strip().split())))
# Out:
#   4%|▎         | 61/1703 [00:00<00:09, 182.40it/s]
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# sides bottom back edge along into away way both hand shoulder onto behind over part
# said asked interview warned speaking talked acknowledged noted reported tell called stated telling saying quoted
# say telling do want hear think know sure how else n't why talk believe did
# say telling do want hear think know sure how else n't why talk believe did
# say telling do want hear think know sure how else n't why talk believe did
# said asked interview warned speaking talked acknowledged noted reported tell called stated telling saying quoted
# say telling do want hear think know sure how else n't why talk believe did
# said asked interview warned speaking talked acknowledged noted reported tell called stated telling saying quoted
# said asked interview warned speaking talked acknowledged noted reported tell called stated telling saying quoted
# say telling do want hear think know sure how else n't why talk believe did
# learns explains finds asks teaches says reminds realizes reveals informs describes discovers narrates narrator confronts
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# horrible awful horrendous dreadful horrific horrifying terrifying appalling frightening shocking atrocious tragic hideous ghastly heinous
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# believes feels understands think knows everybody sees everyone anyone says anybody wants else somebody considers
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# indeed think actually thinking really knew believe probably idea 've feel maybe realized why n't
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# indeed think actually thinking really knew believe probably idea 've feel maybe realized why n't
# believe sure guess maybe 're do n't really feel want know why we 'm 've
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# hence therefore consequently thereby furthermore so instead however moreover also although likewise further — latter
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# storms wind gusty gusting thunderstorms squalls downpours gusts rains headwinds storm breezes gales buffeting windstorms
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# storms wind gusty gusting thunderstorms squalls downpours gusts rains headwinds storm breezes gales buffeting windstorms
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# charge charging fees taxes charged expenses allegations counts claims expense costs fines tax fee prosecution
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# charges charging charged fees expense taxes costs expenses fee demand for committed paying tax duties
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# charges charging charged fees expense taxes costs expenses fee demand for committed paying tax duties
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# prosecuted charge charges improperly convicted indicted wrongfully allegedly wrongly paid accused levied punished liable guilty
# charges charging charged fees expense taxes costs expenses fee demand for committed paying tax duties
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# civilian governmental legal non-governmental civic liberties judicial public nongovernmental humanitarian citizen organizations rights civilians enforcement
# washing scrubbing cleanup clean cleaners clean-up sanitation laundry drying wash disinfecting remediation disinfection cleanliness cleaner
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# washing scrubbing cleanup clean cleaners clean-up sanitation laundry drying wash disinfecting remediation disinfection cleanliness cleaner
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# cleaning wash cleaner potable sanitize scrubbing disinfect washing unpolluted sanitation cleanliness uncluttered drinkable disinfection cleaned
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
#   8%|▊         | 141/1703 [00:01<00:14, 108.04it/s]
# coach trainers teams coaching players teammates athletes instructors sports quarterbacks basketball assistants trainer coached administrators
# coach trainers teams coaching players teammates athletes instructors sports quarterbacks basketball assistants trainer coached administrators
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# coach trainers teams coaching players teammates athletes instructors sports quarterbacks basketball assistants trainer coached administrators
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# coaches advocaat coached manager coaching parcells trainer hiddink mcclaren teammates belichick basketball athlete pitino squad
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# damp humid wet moist arid moisture drying soils drier wetland dried acidic salty barren humidity
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# complete comprehensive proper whole own adequate present extensive entire sort meaningful appropriate substantial purpose sufficient
# heap piles pile stacks rubble debris piled garbage rubbish mounds trash piling rotting litter ruins
# heap piles pile stacks rubble debris piled garbage rubbish mounds trash piling rotting litter ruins
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# heaps pile garbage trash rubbish piles stack muck rubble litter debris dirt piling dustbin sludge
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# working jobs employment work hiring labor workforce task employee personnel duties doing employees managerial tasks
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# belated early delayed announced announcing tardy belatedly canceled shortly departure heralded cancelled earlier abruptly beginning
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# nouveau neue nueva modern la nieuwe city nuova colonia nouvelle the nuevo paris news punto
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# usually sometimes frequently generally normally rarely occasionally typically routinely commonly invariably seldom otherwise also rather
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# just not well even but no either so neither alone because simply n't merely if
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
# pulses vibration waveform pulsation amplitude heartbeat attenuation propagation coil tuning modulation amplification vibrations electromagnetic oscillations
# pulses vibration waveform pulsation amplitude heartbeat attenuation propagation coil tuning modulation amplification vibrations electromagnetic oscillations
# pulses vibration waveform pulsation amplitude heartbeat attenuation propagation coil tuning modulation amplification vibrations electromagnetic oscillations
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
#  13%|█▎        | 223/1703 [00:02<00:16, 90.77it/s]
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
# pulse impulses legumes oscillations waveforms plugs outputs grains threads harmonics spikes tubers bulbs strands triggers
# pulses vibration waveform pulsation amplitude heartbeat attenuation propagation coil tuning modulation amplification vibrations electromagnetic oscillations
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# putting make bring them made out get take further taking could even taken would over
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# definitely obviously indeed certainly absolutely truly sure quite feel rather 're think surely seems actually
# reverted returning subsequently restored transferred afterwards withdrawn moved recovered removed thereafter reinstated settled surrendered discontinued
# returns returning repatriation departure returned back recovery refund repayment transfer surrender leave handover eventual pay
# reverted returning subsequently restored transferred afterwards withdrawn moved recovered removed thereafter reinstated settled surrendered discontinued
# returns returning repatriation departure returned back recovery refund repayment transfer surrender leave handover eventual pay
# returns returning repatriation departure returned back recovery refund repayment transfer surrender leave handover eventual pay
# returns returning repatriation departure returned back recovery refund repayment transfer surrender leave handover eventual pay
# leaving arriving returned return arrival entering back coming departing returns arrived refugees taking leave stopped
# leaving arriving returned return arrival entering back coming departing returns arrived refugees taking leave stopped
# reverted returning subsequently restored transferred afterwards withdrawn moved recovered removed thereafter reinstated settled surrendered discontinued
# return proceeds earnings profits returning due gains expected revenues back profit demand revenue pay coming
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# hangars cabins hangers outhouses bins shafts enclosures boathouses warehouses piles stacks shacks cages lockers shed
# hangars cabins hangers outhouses bins shafts enclosures boathouses warehouses piles stacks shacks cages lockers shed
# spilling wiping decreasing excess excretion stripping erasing diminishing falling clearing waste reducing clogging shed removing
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# sheds pile cement down shedding hangar locked dropped closed blocks up fell dipped pull floors
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# gently tenderly sweetly calmly gracefully happily kindly politely delicately quietly cheerfully loudly excitedly boldly incessantly
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# especial particular extraordinary exceptional security hoc unique conjunction quality specially appropriate musique spéciale personal standard
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# approach different methods manner aspects sort kinds certain approaches way patterns solutions develop how changing
# approach different methods manner aspects sort kinds certain approaches way patterns solutions develop how changing
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# view this so approach course ways sort means turn fact kind we is manner through
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# some than over around nearly approximately roughly there more for further least between much this
# roaches cockroaches insects beetles parasites pests worms mosquitoes fleas bug maggots bedbugs rodents termites critters
#  19%|█▉        | 325/1703 [00:02<00:08, 155.76it/s]
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# roaches cockroaches insects beetles parasites pests worms mosquitoes fleas bug maggots bedbugs rodents termites critters
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# roaches cockroaches insects beetles parasites pests worms mosquitoes fleas bug maggots bedbugs rodents termites critters
# roaches cockroaches insects beetles parasites pests worms mosquitoes fleas bug maggots bedbugs rodents termites critters
# bugs glitch pest worm infestation insect viruses virus plague beetle cockroach parasite flaw insects pests
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# celtics coyotes oilers bull grizzlies knicks cowboys pacers lakers buffalo lions cavaliers bobcats panthers cavs
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# ox bulls elephant jaguar lion taurus oxen leopard mule elk boar barako coyote horse rider
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# educational teaching learning curriculum school schooling academic educación social schools vocational pedagogy curricula public pedagogical
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# boys daughters girl children women mothers men sisters kids daughter woman teenagers females child moms
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# daughter woman wife girlfriend mother girls mom lady kid baby child maid boyfriend daughters sweetheart
# boys daughters girl children women mothers men sisters kids daughter woman teenagers females child moms
# boys daughters girl children women mothers men sisters kids daughter woman teenagers females child moms
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# nice nothing beautiful well bueno okay yeah you love pretty happy true ok mama something
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# difficult tough enough easy harder too extremely strong serious rather very complicated easier tricky harsh
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# snowfall heavy deadliest bloodiest snowfalls rains torrential worst snowstorm brunt biggest hardest fiercest heavier lightest
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# intense costly huge tough massive difficult cumbersome severe harsh strong onerous low stiff intensive burdensome
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# either so then even thus simply rather also though however sometimes while further once actually
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# living life alive lives viva now alone love encore always well be in reside people
# crowds sledgehammers gatherings poles prayers crowd believers bands rallies worshippers fans mourners clusters gather worshipers
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# crowds sledgehammers gatherings poles prayers crowd believers bands rallies worshippers fans mourners clusters gather worshipers
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# crowds sledgehammers gatherings poles prayers crowd believers bands rallies worshippers fans mourners clusters gather worshipers
# crowds sledgehammers gatherings poles prayers crowd believers bands rallies worshippers fans mourners clusters gather worshipers
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# messe masse masses mace disperse annihilation extermination dispersed requiem ground demonstration destruction cluster deportations cleansing
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
#  24%|██▍       | 411/1703 [00:03<00:05, 225.14it/s]
# match coincidences appearances tournaments sets pairs pairings game matchups match-ups repetitions contests friendlies foursomes fourball
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# final play game matches replay draw score semifinal scoring pairing qualifying matching semi-final finals chance
# sentiments feelings whims emotions mood attitudes sensations perceptions thoughts behaviours behaviors impulses passions sensibilities nuances
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# sentiments feelings whims emotions mood attitudes sensations perceptions thoughts behaviours behaviors impulses passions sensibilities nuances
# sentiments feelings whims emotions mood attitudes sensations perceptions thoughts behaviours behaviors impulses passions sensibilities nuances
# sentiments feelings whims emotions mood attitudes sensations perceptions thoughts behaviours behaviors impulses passions sensibilities nuances
# atmosphere feeling sentiment ambience emotion sense ambiance sentiments calm moods attitude emotions vibe euphoria excitement
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# telephone cellphone phones telephones telephony messaging wireless landline handsets cellular fax communications handset cellphones pager
# positions offices jobs post seats personnel appointments stations vacancies places job boards vacant posting sectors
# posts page job position site check posted posting through time current publication next after for
# positions offices jobs post seats personnel appointments stations vacancies places job boards vacant posting sectors
# positions offices jobs post seats personnel appointments stations vacancies places job boards vacant posting sectors
# posts page job position site check posted posting through time current publication next after for
# posts page job position site check posted posting through time current publication next after for
# posts page job position site check posted posting through time current publication next after for
# posts page job position site check posted posting through time current publication next after for
# posts page job position site check posted posting through time current publication next after for
# posts page job position site check posted posting through time current publication next after for
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# kg kilos pound kilograms lb kilogrammes lbs kilogram £ € lire shillings euros kilo 175
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# kg kilos pound kilograms lb kilogrammes lbs kilogram £ € lire shillings euros kilo 175
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# pounds kilogram kilo euro lire ounce lb euros ounces francs lira cents € kilograms franc
# unprocessed crude untreated dried excess uncooked wastes liquid canned undiluted ingredients grain food feed waste
# unprocessed crude untreated dried excess uncooked wastes liquid canned undiluted ingredients grain food feed waste
# unprocessed crude untreated dried excess uncooked wastes liquid canned undiluted ingredients grain food feed waste
# ...
# functions functioning functional hence corresponding component set thus integral defined mode therefore means similar particular
# improvisation drum concert recording rhythm jelly guitar hop demo jazz drumming duo drums musicians noise
# improvisation drum concert recording rhythm jelly guitar hop demo jazz drumming duo drums musicians noise
# improvisation drum concert recording rhythm jelly guitar hop demo jazz drumming duo drums musicians noise
# improvisation drum concert recording rhythm jelly guitar hop demo jazz drumming duo drums musicians noise
# marmalades jellies bottlenecks compotes snarled diversions snarls frosts congestions detours washouts chutneys hailstorms congestion clogging
# marmalades jellies bottlenecks compotes snarled diversions snarls frosts congestions detours washouts chutneys hailstorms congestion clogging
# marmalades jellies bottlenecks compotes snarled diversions snarls frosts congestions detours washouts chutneys hailstorms congestion clogging
# marmalades jellies bottlenecks compotes snarled diversions snarls frosts congestions detours washouts chutneys hailstorms congestion clogging
# marmalades jellies bottlenecks compotes snarled diversions snarls frosts congestions detours washouts chutneys hailstorms congestion clogging
# improvisation drum concert recording rhythm jelly guitar hop demo jazz drumming duo drums musicians noise
# runs brings is makes carries draw goes takes which lead turns draws further gives both
# turn make leading bring push create put pull start boost hold leads set run take
# turn make leading bring push create put pull start boost hold leads set run take
# turn make leading bring push create put pull start boost hold leads set run take
# runs brings is makes carries draw goes takes which lead turns draws further gives both
# turn make leading bring push create put pull start boost hold leads set run take
# runs brings is makes carries draw goes takes which lead turns draws further gives both
# turn make leading bring push create put pull start boost hold leads set run take
# turn make leading bring push create put pull start boost hold leads set run take
#  95%|█████████▍| 1615/1703 [00:06<00:00, 338.28it/s]
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# documents articles newspapers journals document publication records diaries books files newspaper notes essays written publish
# documents articles newspapers journals document publication records diaries books files newspaper notes essays written publish
# documents articles newspapers journals document publication records diaries books files newspaper notes essays written publish
# print printing papers printed document newspaper documents books copy book journal watermarked pamphlet photocopy bulletin
# adopted introduced enacted pass made approved brought took then entered came later after issued implemented
# adopted introduced enacted pass made approved brought took then entered came later after issued implemented
# passes passed passing get through enter make turn passage allowed allow entry allowing back carry
# pass passes speeding turning catching passage driving entering entry passed entrance taking rushing through crossing
# passes passed passing get through enter make turn passage allowed allow entry allowing back carry
# pass passes speeding turning catching passage driving entering entry passed entrance taking rushing through crossing
# pass passing carries runs touchdown touchdowns route passage through leads turns passed onto goes out
# passes passed passing get through enter make turn passage allowed allow entry allowing back carry
# passes passed passing get through enter make turn passage allowed allow entry allowing back carry
# adopted introduced enacted pass made approved brought took then entered came later after issued implemented
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# wealthier poorest richer impoverished poor disadvantaged weaker economically worse vulnerable needy underdeveloped affluent destitute lower
# disadvantaged destitute impoverished needy poorer underdeveloped poorest poverty-stricken underprivileged indigent chronically downtrodden uneducated inadequate unsafe
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# stay remainder resting remain remains remaining stays kept remained once stayed back few keep leave
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# law nothing way be fair droit point go always change justice good morally not something
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# necklaces earrings brooches beads bracelets pendants loops bangles strings ring tattoos bells piercings collars spikes
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# necklaces earrings brooches beads bracelets pendants loops bangles strings ring tattoos bells piercings collars spikes
# rings circle annulus loops loop coil string bead concentric sheath groove rope knot helical cord
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrap leftover shreds crumbs debris pile leftovers scavenged wrapping envelopes discard discarded pieces rotting carcasses
# scrap leftover shreds crumbs debris pile leftovers scavenged wrapping envelopes discard discarded pieces rotting carcasses
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# scrap leftover shreds crumbs debris pile leftovers scavenged wrapping envelopes discard discarded pieces rotting carcasses
# scrapping discarded scraps recycling waste scrapped discard trash dump abolish disposal remove heap recycle rubbish
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# clandestine covert secrets spy confidential hiding hidden spying espionage alleged secrecy hide eavesdropping illegal undercover
# 100%|██████████| 1703/1703 [00:06<00:00, 263.01it/s]
# caught shoot fired shooting punched hit knocked kicked killed beaten pulled missed accidentally shots struck
# caught shoot fired shooting punched hit knocked kicked killed beaten pulled missed accidentally shots struck
# rounds bullets strokes punches shoot volleys blows shot gunshots beatings bursts knock shooters gunshot shooting
# caught shoot fired shooting punched hit knocked kicked killed beaten pulled missed accidentally shots struck
# rounds bullets strokes punches shoot volleys blows shot gunshots beatings bursts knock shooters gunshot shooting
# rounds bullets strokes punches shoot volleys blows shot gunshots beatings bursts knock shooters gunshot shooting
# rounds bullets strokes punches shoot volleys blows shot gunshots beatings bursts knock shooters gunshot shooting
# caught shoot fired shooting punched hit knocked kicked killed beaten pulled missed accidentally shots struck
# rounds bullets strokes punches shoot volleys blows shot gunshots beatings bursts knock shooters gunshot shooting
# caught shoot fired shooting punched hit knocked kicked killed beaten pulled missed accidentally shots struck
# shows shown display showing showed displayed presented demonstrate yet picture appear showcase feature how exhibit
# showed demonstrated displayed show indicated presented showing shows revealed reflected described contained made noted found
# shows shown display showing showed displayed presented demonstrate yet picture appear showcase feature how exhibit
# showed demonstrated displayed show indicated presented showing shows revealed reflected described contained made noted found
# shows shown display showing showed displayed presented demonstrate yet picture appear showcase feature how exhibit
# displaying shown displayed demonstrating showed shows show display reflecting depicting indicating exhibiting illustrating noting picture
# shows shown display showing showed displayed presented demonstrate yet picture appear showcase feature how exhibit
# shows shown display showing showed displayed presented demonstrate yet picture appear showcase feature how exhibit
# showed demonstrated displayed show indicated presented showing shows revealed reflected described contained made noted found
# showed demonstrated displayed show indicated presented showing shows revealed reflected described contained made noted found
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# meandering lanes trail zigzagging paved paths tortuous roads rutted curving twisty braiding crossing route path
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# meandering lanes trail zigzagging paved paths tortuous roads rutted curving twisty braiding crossing route path
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# meandering lanes trail zigzagging paved paths tortuous roads rutted curving twisty braiding crossing route path
# exhausted circuited stilted boring tiring groggy tiresome pedantic tired plodding slurring ponderous fatigued tedious verbose
# winds waves downwind tides currents rain storms turbine turbines storm gusting gust thunderstorm upwind gusty
# injury wounds injuries injured wounded hurt shoulder gunshot sore shrapnel knee stab bruised wounding concussion
# job worked work employed doing done labor help task establish business making create for make
# working job undertaking process operation action business task done undertaken tasks undertake operations conduct actions
# working collaborated performed hired acted done conducted managed served recently operated employed met learned tried
# working collaborated performed hired acted done conducted managed served recently operated employed met learned tried
# working collaborated performed hired acted done conducted managed served recently operated employed met learned tried
# working job undertaking process operation action business task done undertaken tasks undertake operations conduct actions
# job worked work employed doing done labor help task establish business making create for make
# working job undertaking process operation action business task done undertaken tasks undertake operations conduct actions
# job worked work employed doing done labor help task establish business making create for make
# job worked work employed doing done labor help task establish business making create for make

# %% [markdown]
# After running zipout.py and check.py, we get a score of 44.92.

# %% [markdown]
# ## 2. Incorporate Context Words (score = 32.12)

# %% [markdown]
# Following the instructions of the homework, we try to augment the baseline solution to incorporate the context around the target word to find better substitute words. "After reading the paper A Simple Word Embedding Model for Lexical Substitution", we first try the BalAdd measure in Table one to introduce a context-sensitive substitutability
# metric for estimating the suitability of a lexical substitute for a target word in a given sentential context:

# %%
def incorporating_context_words(wvecs, wvecKey, sentence, index, substitutes, topn):
    # Incorporating Context Words
    sort_substitutes = []
    non_target_words_set = set()
    for word in sentence[:index]:
        non_target_words_set.add(word)
    for word in sentence[index+1:len(sentence)]:
        non_target_words_set.add(word)
    non_target_words = non_target_words_set.intersection(wvecKey)
    target = sentence[index]
    num_non_target_words = len(non_target_words)
    for substitute in substitutes:
        numerator = cos(wvecs[substitute], wvecs[target]) * num_non_target_words
        if(num_non_target_words == 0):
            continue
        for non_target_word in non_target_words:
            numerator = numerator + cos(wvecs[substitute], wvecs[non_target_word])
        denominator = num_non_target_words * 2 # divide by number of non target word, also divide by 2 for getting average after adding target and non target cos
        score = numerator/denominator
        sort_substitutes.append((substitute, score))
    sort_substitutes = sorted(sort_substitutes, key=lambda x: x[1], reverse=False)
    # print(sort_substitutes)
    return map(lambda x: x[0], sort_substitutes[:topn])

# %% [markdown]
# Changing the parameter use_context_word=True, and follow the above steps, using zipout.py and check.py, we get a score for incorporating context words of score=32.12, which does not improve the original method.

# %% [markdown]
# ## 3. Changing α and β  (α=1,β=2.19, score= 48.32)

# %% [markdown]
# Instead of incorporating context words into the solution, we try to find a better score by changing the values of α and β. To change the value, assign different values when calling the function "retrofitting(wordVectors, lexicon, numberOfIteration, alpha, beta). Repeating the substitution steps and we have the following relationship:

# %% [raw]
#    (α, β)       score
#
#  (α=1,β=2)      47.74
# (α=1,β=2.19)    48.32
# (α=1,β=2.2)     48.27
# (α=1,β=2.21)    47.87
# (α=1,β=2.3)     47.86

# %% [markdown]
# Thus we have reached a higher score 48.32 when α=1,β=2.19.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this task, we have finishes three taskes:

# %% [markdown]
# (1) Implement the baseline solution

# %% [markdown]
# (2) Incorporate context words into the baseline solution

# %% [markdown]
# (3) Adjusting parameters α,β for the baseline solution

# %% [markdown]
# After these three tasks, we have reach a score 48.32 for this problem.
